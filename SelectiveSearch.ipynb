# %%
import Utils
img = Utils.readImage("/Users/nishatiwari/PycharmProjects/OpenCV/HW2_Data/JPEGImages/007346.jpg")
window_name="Selctive search for image 000480"
from matplotlib import pyplot as plt
plt.imshow(img)

# %%
bboxes=Utils.applySelectiveSearch(img, False)

# %%
img_with_bboxes=Utils.drawBoxesInImagePredBox(img, 100, bboxes,(0,0,255))

# %%
# %pylab inline
plt.imshow(img_with_bboxes)
plt.show()
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
#import Utils as utils
xmlPath='/Users/nishatiwari/PycharmProjects/OpenCV/HW2_Data/Annotations/007346.xml'
GTimageObjects=Utils.parseXMLAndFindObjects(xmlPath)

# %%
img_with_gt_bboxes=Utils.drawBoxesInImage(img, len(GTimageObjects), GTimageObjects, (0,255,0))

# %%
# %pylab inline
plt.imshow(img_with_gt_bboxes)
plt.show()
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
precision, recall, selectedBoxes, =Utils.eval_iou( bboxes, GTimageObjects)

# %%
img_with_selectedBboxes=Utils.drawBoxesInImagePredBox(img, len(selectedBoxes), selectedBoxes, (0,0,255))

# %%
# %pylab inline
plt.imshow(img_with_selectedBboxes)
plt.show()
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
print(precision,recall)
# Out:
# 0.0008577380223011886 1.0
