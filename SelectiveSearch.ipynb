# %% [markdown]
# # Jupyter Notebook to Run Selective Search for an Image
# (This can be automated to loop through various images)

# %% [markdown]
# ### Reading and plotting an image

# %%
import Utils
img = Utils.readImage("/Users/nishatiwari/PycharmProjects/OpenCV/HW2_Data/JPEGImages/007346.jpg")
# %pylab inline
from matplotlib import pyplot as plt
plt.imshow(img)
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ### Calling Selective Search for the image above with isCombined flag (default as false)

# %%
import SelectiveSearchUtils
bboxes=SelectiveSearchUtils.applySelectiveSearch(img, True)

# %% [markdown]
# ### Plotting the first 100 bounding boxes from Selective Search

# %%
img_with_bboxes=Utils.drawBoxesInImagePredBox(img, 100, bboxes,(0,0,255))
# %pylab inline
plt.imshow(img_with_bboxes)
plt.show()
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ### Parsing Annotations for the given image and plotting the ground truths on the image

# %%
xmlPath='/Users/nishatiwari/PycharmProjects/OpenCV/HW2_Data/Annotations/007346.xml'
GTimageObjects=Utils.parseXMLAndFindObjects(xmlPath)
img_with_gt_bboxes=Utils.drawBoxesInImage(img, len(GTimageObjects), GTimageObjects, (0,255,0))
# %pylab inline
plt.imshow(img_with_gt_bboxes)
plt.show()
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ### Calculating IOU and plotting all the bounding boxes greater than the IOU threshold

# %%
iou_threshold=0.5
mabo, precision, recall, selectedBoxes,maxOverlap_bboxes =Utils.calculateIOU( bboxes, GTimageObjects, iou_threshold)
img_with_selectedBboxes=Utils.drawBoxesInImagePredBox(img_with_gt_bboxes, len(selectedBoxes), selectedBoxes, (0,0,255))
# %pylab inline
plt.imshow(img_with_selectedBboxes)
plt.show()
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
img_with_selectedBboxes=Utils.drawBoxesInImagePredBox(img_with_gt_bboxes, len(maxOverlap_bboxes), maxOverlap_bboxes, (0,0,255))
# %pylab inline
plt.imshow(img_with_selectedBboxes)
plt.show()
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ### Printing Mean Average Best Overlap (MABO), Precision, Recall, and No. of Bounding Boxes found

# %%
print("MABO::",mabo, "PRECISION::", precision,"RECALL::", recall, "No. of Bounding Boxes Found::", len(selectedBoxes))
# Out:
# MABO:: 0.7885035270734403 PRECISION:: 0.3691983122362869 RECALL:: 100.0 No. of Bounding Boxes Found:: 54
